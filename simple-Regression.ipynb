# %%
import pandas as pd

# %%
df = pd.read_csv("sampleTrain_test.csv")

# %%
df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = df[["Age"]]
y = df[["Premium"]]
plt.xlabel(df["Age"])
plt.ylabel(df["Premium"])
plt.scatter(x,y)
plt.show()

# %%
import seaborn as sns

# %%
sns.lmplot(x="Age",y="Premium",data = df)

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
type(reg)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
reg.fit(df[["Age"]],df['Premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[21.0]])
# Out:
# C:\Users\priyanshu verma\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\priyanshu verma\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65100.])

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23899.999999999985
